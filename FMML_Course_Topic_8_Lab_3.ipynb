# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthamsai117/FMML-Lab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-12 06:15:10--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   143MB/s    in 0.5s
#
# 2024-04-12 06:15:11 (143 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2055 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15924  1606.07993v1  Biomedical information extraction (BioIE) is i...    cs
# 6130   1608.00704v3  This work proposes a new algorithm for automat...  stat
# 21518   0811.4208v1  Min-cut clustering, based on minimizing one of...  stat
# 6086   1607.00485v1  In this paper, we consider the joint task of s...  stat
# 34119   1401.5644v1  Document Clustering is a branch of a larger ar...    cs
# ...             ...                                                ...   ...
# 12873  1801.01281v1  With more and more household objects built on ...    cs
# 10053  1701.03162v1  In this paper, we try to predict the winning t...  stat
# 22743  1705.08716v1  The volume of data generated by internet and s...  stat
# 14657   0806.3787v2  Measuring the similarity of short written cont...    cs
# 22787  1706.08263v1  Data lying in a high-dimensional ambient space...  stat
#
#                                                    title  year  \
# 15924  Learning for Biomedical Information Extraction...  2016
# 6130   Identifiable Phenotyping using Constrained Non...  2016
# 21518  An information-theoretic derivation of min-cut...  2008
# 6086   Group Sparse Regularization for Deep Neural Ne...  2016
# 34119  A new keyphrases extraction method based on su...  2014
# ...                                                  ...   ...
# 12873  Object segmentation in depth maps with one use...  2018
# 10053          Real-time eSports Match Result Prediction  2016
# 22743  An experimental study of graph-based semi-supe...  2017
# 14657  Computational Approaches to Measuring the Simi...  2008
# 22787  Efficient Manifold and Subspace Approximations...  2017
#
#                                                 keywords
# 15924  [biomedical, information, extraction, importan...
# 6130   [algorithm, automated, simultaneous, phenotypi...
# 21518  [clustering, minimizing, heuristic, functions,...
# 6086   [simultaneously, optimizing, generally, separa...
# 34119  [clustering, scientific, unsupervised, classif...
# ...                                                  ...
# 12873  [household, obsolescence, population, hazardou...
# 10053  [multiplayer, weaknesses, individual, progress...
# 22743  [generated, increasing, efficient, extracting,...
# 14657  [measuring, similarity, fundamental, processin...
# 22787  [dimensional, intrinsic, dimension, particular...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15924    [biomedical, information, extraction, importan...
# 6130     [algorithm, automated, simultaneous, phenotypi...
# 21518    [clustering, minimizing, heuristic, functions,...
# 6086     [simultaneously, optimizing, generally, separa...
# 34119    [clustering, scientific, unsupervised, classif...
#                                ...
# 36825    [graphical, representation, statistical, embod...
# 14988    [demonstrate, attention, grammatical, identifi...
# 22225    [computation, bottleneck, subsampling, efficie...
# 32396    [symmetric, approximation, extensively, eigenv...
# 25358    [hyperspectral, classification, architectures,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8781 words.
# Out of those 4549 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="88e2c1c0-bc94-47dd-8dbd-d21641ae368e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88e2c1c0-bc94-47dd-8dbd-d21641ae368e")) {                    Plotly.newPlot(                        "88e2c1c0-bc94-47dd-8dbd-d21641ae368e",                        [{"x":["information","methodological","techniques","therefore","applications","summarizing","approaches","integrative","systematically","development","influential","generation","different","biomedical","important","pharmacovigilance","including","extraction","constrained","identifiable","mortality","phenotypes","electronic","phenotyping","institutions","algorithm","estimation","qualitative","conditions","factorization","technique","assessment","clinically","simultaneous","automated","healthcare","constraints","empirical","predictive","occurring","interpretable","augmented","anchoring","mechanism","regularized","approximated","generalization","optimizing","relevance","tremendous","principle","derivation","minimizing","community","partitioned","framework","motivated","communities","introduced","heuristic","segmentation","heuristics","generated","bottleneck","partition","algorithmic","partitioning","functions","probability","facilitating","theoretic","relationships","stochastic","structure","clustering","performing","realistic","penalties","recognition","aforementioned","separately","connections","formulation","resulting","evaluation","generally","classical","extremely","performances","optimization","depending","extensive","regularization","simultaneously","regression","classification","comparing","handwritten","competitive","experimental","specifically","independent","unsupervised","documents","hierarchical","extracted","representation","algorithms","increases","scientific","interested","languages","keyphrases","negatively","efficient","extracting","investigation","eliminate","collection","similarity","agglomerative","accompanied","unlabeled","underlying","introduce","alternative","furthermore","arbitrary","assumption","distribution","computational","intuitive","versatile","connection","illustrated","biological","dimensional","structures","originating","indicates","guarantees","reference","graphical","homogeneous","distances","providing","respecting","properties","placement","automatic","detection","attentive","directional","annotation","representations","attending","engineering","clickbait","evaluating","recurrent","challenge","involving","comparison","quadratic","reinforcement","exponentially","advertising","prominent","convergence","established","logarithmic","asymptotic","dimensions","particular","dimension","describing","controller","bipartite","assigning","parameters","objective","retrospective","baselines","probabilistic","evaluated","initialization","availability","likelihood","parameter","condition","prediction","effective","outperforms","accommodate","observations","extension","intuition","appropriate","uncertain","hypothesis"],"y":[706,5,381,140,403,12,440,1,24,130,11,137,741,11,325,1,257,102,49,1,3,2,18,0,4,799,221,49,129,34,222,48,3,24,85,6,145,154,57,16,34,30,0,101,33,16,93,41,31,5,47,10,37,67,7,557,58,22,123,49,208,39,165,12,27,42,17,214,181,9,47,58,126,325,167,83,48,3,400,17,31,45,89,136,256,66,110,38,41,275,26,159,76,123,135,515,64,26,108,363,179,124,157,75,105,113,365,599,57,25,28,84,3,3,396,64,29,12,89,140,6,9,45,110,312,97,168,73,72,229,275,35,6,41,22,38,181,123,6,23,70,39,56,16,22,78,2,221,6,186,335,7,19,54,253,2,52,2,62,138,151,54,122,38,108,24,3,13,113,47,15,21,41,298,77,40,10,5,11,263,135,0,48,171,127,25,23,64,123,43,214,264,274,7,72,98,23,84,31,55],"type":"bar"},{"x":["information","methodological","techniques","therefore","applications","summarizing", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4549,), (4549, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Schema</span> <span style=''>Networks</span> <span style=''>Zero</span> <span style=''>shot</span> <span style=''>Transfer</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style=''>Causal</span> <span style=''>Model</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Intuitive</span> <span style=''>Physics</span> <br/><br/><span style=''>The</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3217391304347826);'>adaptation</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>planning</span> <span style=''>domains</span> <span style=''>has</span> <span style=''>yielded</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>remarkable</span> <span style=''>progress</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>tasks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonetheless</span> <span style=''>progress</span> <span style=''>on</span> <span style=''>task</span> <span style=''>to</span> <span style=''>task</span> <span style=''>transfer</span> <span style=''>remains</span> <span style=''>limited</span> <span style=''>In</span> <span style=''>pursuit</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>Schema</span> <span style=''>Network</span> <span style=''>an</span> <span style=''>object</span> <span style=''>oriented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>physics</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>simulator</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>disentangling</span> <span style=''>multiple</span> <span style=''>causes</span> <span style=''>of</span> <span style=''>events</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.7086092715231787);'>reasoning</span> <span style=''>backward</span> <span style=''>through</span> <span style=''>causes</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>goals</span> <span style=''>The</span> <span style=''>richly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.5614617940199335);'>architecture</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Schema</span> <span style=''>Network</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.6827586206896552);'>environment</span> <span style=''>directly</span> <span style=''>from</span> <span style=''>data</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>Schema</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Asynchronous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Advantage</span> <span style=''>Actor</span> <span style=''>Critic</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8);'>Progressive</span> <span style=''>Networks</span> <span style=''>on</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style=''>Learning</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Truncated</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>(TGGM)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>designing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>learning</span> <span style=''>A</span> <span style=''>TGGM</span> <span style=''>is</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>(GGM)</span> <span style=''>with</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>truncated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>are</span> <span style=''>assumed</span> <span style=''>latent</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrated</span> <span style=''>out</span> <span style=''>to</span> <span style=''>induce</span> <span style=''>a</span> <span style=''>marginal</span> <span style=''>model</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>the</span> <span style=''>marginal</span> <span style=''>model</span> <span style=''>are</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>and</span> <span style=''>their</span> <span style=''>expected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>We</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>to</span> <span style=''>break</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>model</span> <span style=''>into</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>TGGM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>problems</span> <span style=''>each</span> <span style=''>of</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>solved</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Utility</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>Duality</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>duality</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.32951289398280803);'>distributions</span> <span style=''>and</span> <span style=''>utility</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style=''>Recovery</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simultaneous</span> <span style=''>Presence</span> <span style=''>of</span> <span style=''>Outliers</span> <span style=''>and</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Corruption</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>a</span> <span style=''>data</span> <span style=''>model</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>data</span> <span style=''>matrix</span> <span style=''>D</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>D</span> <span style=''>L</span> <span style=''>S</span> <span style=''>C</span> <span style=''>where</span> <span style=''>L</span> <span style=''>is</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>S</span> <span style=''>an</span> <span style=''>element</span> <span style=''>wise</span> <span style=''>sparse</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>C</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>whose</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>columns</span> <span style=''>are</span> <span style=''>outlying</span> <span style=''>data</span> <span style=''>points</span> <span style=''>To</span> <span style=''>date</span> <span style=''>robust</span> <span style=''>PCA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>solely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>models</span> <span style=''>with</span> <span style=''>either</span> <span style=''>S</span> <span style=''>or</span> <span style=''>C</span> <span style=''>but</span> <span style=''>not</span> <span style=''>both</span> <span style=''>As</span> <span style=''>such</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>cannot</span> <span style=''>account</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneous</span> <span style=''>element</span> <span style=''>wise</span> <span style=''>and</span> <span style=''>column</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corruptions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>new</span> <span style=''>robust</span> <span style=''>PCA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>is</span> <span style=''>robust</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneous</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corruption</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>hinges</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sparsely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrupted</span> <span style=''>column</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expansion</span> <span style=''>of</span> <span style=''>a</span> <span style=''>column</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10028449502133713)
# 	experimental (0.1290896159317212)
# 	representation (0.129800853485064)
# 	architecture (0.08357041251778094)
# 	segmentation (0.07396870554765292)
# 	information (0.25106685633001424)
# 	detection (0.11913229018492176)
# 	different (0.2635135135135135)
# 	convolutional (0.13584637268847796)
# 	recognition (0.1422475106685633)
#
# Some Statistics words are:
# 	stochastic (0.12977867203219315)
# 	variational (0.10462776659959759)
# 	theoretical (0.15442655935613683)
# 	statistical (0.15241448692152917)
# 	variables (0.14185110663983905)
# 	algorithm (0.38480885311871227)
# 	distribution (0.18259557344064387)
# 	dimensional (0.18108651911468812)
# 	regression (0.17756539235412475)
# 	inference (0.21277665995975856)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8ab9e222-8020-4faa-9c69-85d94250ffc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ab9e222-8020-4faa-9c69-85d94250ffc8")) {                    Plotly.newPlot(                        "8ab9e222-8020-4faa-9c69-85d94250ffc8",                        [{"x":["information","methodological","techniques","therefore","applications","summarizing","approaches","integrative","systematically","development","influential","generation","different","biomedical","important","pharmacovigilance","including","extraction","constrained","identifiable","mortality","phenotypes","electronic","phenotyping","institutions","algorithm","estimation","qualitative","conditions","factorization","technique","assessment","clinically","simultaneous","automated","healthcare","constraints","empirical","predictive","occurring","interpretable","augmented","anchoring","mechanism","regularized","approximated","generalization","optimizing","relevance","tremendous","principle","derivation","minimizing","community","partitioned","framework","motivated","communities","introduced","heuristic","segmentation","heuristics","generated","bottleneck","partition","algorithmic","partitioning","functions","probability","facilitating","theoretic","relationships","stochastic","structure","clustering","performing","realistic","penalties","recognition","aforementioned","separately","connections","formulation","resulting","evaluation","generally","classical","extremely","performances","optimization","depending","extensive","regularization","simultaneously","regression","classification","comparing","handwritten","competitive","experimental","specifically","independent","unsupervised","documents","hierarchical","extracted","representation","algorithms","increases","scientific","interested","languages","keyphrases","negatively","efficient","extracting","investigation","eliminate","collection","similarity","agglomerative","accompanied","unlabeled","underlying","introduce","alternative","furthermore","arbitrary","assumption","distribution","computational","intuitive","versatile","connection","illustrated","biological","dimensional","structures","originating","indicates","guarantees","reference","graphical","homogeneous","distances","providing","respecting","properties","placement","automatic","detection","attentive","directional","annotation","representations","attending","engineering","clickbait","evaluating","recurrent","challenge","involving","comparison","quadratic","reinforcement","exponentially","advertising","prominent","convergence","established","logarithmic","asymptotic","dimensions","particular","dimension","describing","controller","bipartite","assigning","parameters","objective","retrospective","baselines","probabilistic","evaluated","initialization","availability","likelihood","parameter","condition","prediction","effective","outperforms","accommodate","observations","extension","intuition","appropriate","uncertain","hypothesis","generalized","observation","formalize","associated","likelihoods","experiments","intuitively","hypotheses","describes","conditional","uncertainty","posteriors","robustness","minimally","construct","demonstrate","increasing","distorted","adversarial","misclassified","perturbed","vulnerable","difficulty","distortion","proposals","verification","retraining","methodology","automatically","adaptation","expressed","instruments","compliance","consisting","researchers","relations","practitioners","construction","knowledge","achieving","distributed","examining","identification","revealing","spatiotemporal","performance","formation","excellent","population","phenomena","detecting","intentions","published","inferring","affective","influencing","statistic ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	phenotyping
# 	anchoring
# 	retrospective
# 	penalization
# 	concentrates
# 	questionnaires
# 	criticisms
# 	concordance
# 	preconditioning
# 	maximisation
# 	determinants
# 	multipartite
# 	endpoints
# 	inspecting
# 	transplantation
# 	ergodicity
# 	cubically
# 	surrogates
# 	seasonality
# 	ferromagnetic
# Some words which never appear in Statistics papers:
# 	keyphrases
# 	attending
# 	clickbait
# 	compliance
# 	affective
# 	defeasible
# 	contention
# 	inevitably
# 	evidential
# 	researches
# 	scholarly
# 	occlusions
# 	registering
# 	connective
# 	extendable
# 	tournaments
# 	localizing
# 	thereafter
# 	patterned
# 	skeletons

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061005846521167e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7833333333333333
